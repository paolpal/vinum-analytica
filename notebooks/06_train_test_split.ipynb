# %%
from vinum_analytica.data.dataset import WineDatasetManager # type: ignore

# %%
dataset = WineDatasetManager.read_csv('../data/raw/clean_data_classification.csv')
dataset.preprocess()
dataset.save('../data/processed/clean_data_classification.csv')

# %%
dataset = WineDatasetManager()
dataset.load('../data/processed/clean_data_classification.csv')

# %%
train, test = dataset.split(random_state=7593)

# %%
from vinum_analytica.visualization.plots import Plotter # type: ignore
plotter = Plotter()

# %%
plotter.plot_variety_count(train)

# %%
plotter.plot_variety_count(test)

# %%
train.save('../data/processed/train_classification.csv')
test.save('../data/processed/test_classification.csv')
